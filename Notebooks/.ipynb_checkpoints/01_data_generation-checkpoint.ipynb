# %%
# Import and Setup

# %%
import pandas as pd
import numpy as np
from faker import Faker
import random
from datetime import datetime, timedelta

fake = Faker('en_IN')
random.seed(42)
np.random.seed(42)

print("Setup complete")
# Out:
# Setup complete

# %%
# Generate Customers

# %%
NUM_CUSTOMERS = 2000

regions = ["North America", "Europe", "Asia Pacific", "Latin America", "Middle East"]
acquisition_channels = ["Organic", "Paid Ads", "Referral", "Sales Outreach", "Partner"]

start_date = datetime(2023, 1, 1)
end_date = datetime(2025, 12, 31)

customers = []
for customer_id in range(1, NUM_CUSTOMERS + 1):
    days_range = (end_date - start_date).days
    signup_date = start_date + timedelta(days=random.randint(0, days_range))
    
    # Pick tier first, then derive a realistic employee count from that tier
    tier = random.choices(["Small", "Medium", "Enterprise"], weights=[50, 35, 15])[0]
    if tier == "Small":
        employee_count = random.randint(1, 50)
    elif tier == "Medium":
        employee_count = random.randint(51, 500)
    else:
        employee_count = random.randint(501, 5000)
    
    customers.append({
        "customer_id": customer_id,
        "company_name": fake.company(),
        "signup_date": signup_date.date(),
        "region": random.choice(regions),
        "company_size_tier": tier,
        "employee_count": employee_count,
        "acquisition_channel": random.choices(
            acquisition_channels,
            weights=[30, 25, 20, 15, 10]
        )[0]
    })

customers_df = pd.DataFrame(customers)
print(f"Customers created: {len(customers_df)}")
customers_df.head(10)
# Out:
# Customers created: 2000
#    customer_id                  company_name signup_date         region  \
# 0            1                     Ray-Ahuja  2025-06-21   Asia Pacific
# 1            2        Banik, Oommen and Hans  2024-02-29    Middle East
# 2            3                      Rege Inc  2025-12-10  North America
# 3            4               Viswanathan Inc  2023-10-14   Asia Pacific
# 4            5  Sidhu, Dugar and Ranganathan  2023-05-21  Latin America
# 5            6                   Raman Group  2025-05-18  North America
# 6            7           Tiwari, Bedi and Om  2023-08-15  Latin America
# 7            8    Vala, Chaudhari and Pandey  2024-09-02  North America
# 8            9                    Comar-Guha  2024-08-28    Middle East
# 9           10                Dugar-Krishnan  2025-12-25  Latin America
#
#   company_size_tier  employee_count acquisition_channel
# 0            Medium              63            Paid Ads
# 1             Small              13      Sales Outreach
# 2             Small              19             Organic
# 3             Small              42            Referral
# 4             Small              26             Organic
# 5             Small              14             Organic
# 6             Small              30      Sales Outreach
# 7             Small              43            Paid Ads
# 8            Medium             108            Paid Ads
# 9            Medium             157             Organic

# %%
print(customers_df['company_size_tier'].value_counts())
print(customers_df['employee_count'].describe())
# Out:
# company_size_tier
# Small         964
# Medium        740
# Enterprise    296
# Name: count, dtype: int64
# count    2000.000000
# mean      520.393500
# std      1070.247244
# min         1.000000
# 25%        27.000000
# 50%        66.000000
# 75%       374.000000
# max      4990.000000
# Name: employee_count, dtype: float64

# %%
# Customer subscription Table

# %%
plan_tiers = ["Starter", "Pro", "Business", "Enterprise"]
plan_mrr = {"Starter": 29, "Pro": 99, "Business": 299, "Enterprise": 999}
billing_cycles = ["Monthly", "Annual"]

subscriptions = []
for idx, row in customers_df.iterrows():
    customer_id = row["customer_id"]
    signup = pd.to_datetime(row["signup_date"])
    
    # Subscription starts same day as signup (simplification)
    sub_start = signup
    
    # Pick plan tier - bias toward tier matching company size
    if row["company_size_tier"] == "Enterprise":
        tier = random.choices(plan_tiers, weights=[5, 15, 30, 50])[0]
    elif row["company_size_tier"] == "Medium":
        tier = random.choices(plan_tiers, weights=[15, 40, 35, 10])[0]
    else:
        tier = random.choices(plan_tiers, weights=[50, 35, 13, 2])[0]
    
    billing = random.choice(billing_cycles)
    base_mrr = plan_mrr[tier]
    
    # Annual billing gets a small discount reflected in effective MRR
    mrr = base_mrr * 0.85 if billing == "Annual" else base_mrr
    
    # Determine if subscription is still active or cancelled
    is_cancelled = random.random() < 0.25  # 25% of customers have churned at some point
    
    if is_cancelled:
        # Cancellation happens sometime between signup and now
        max_days = (datetime(2025, 12, 31) - sub_start).days
        cancel_after_days = random.randint(30, max(max_days, 31))
        sub_end = sub_start + timedelta(days=cancel_after_days)
        status = "Cancelled"
    else:
        sub_end = None
        status = "Active"
    
    subscriptions.append({
        "subscription_id": idx + 1,
        "customer_id": customer_id,
        "plan_tier": tier,
        "billing_cycle": billing,
        "subscription_start_date": sub_start.date(),
        "subscription_end_date": sub_end.date() if sub_end else None,
        "subscription_status": status,
        "monthly_recurring_revenue": round(mrr, 2)
    })

subscriptions_df = pd.DataFrame(subscriptions)
print(f"Subscriptions created: {len(subscriptions_df)}")
subscriptions_df.head(10)
# Out:
# Subscriptions created: 2000
#    subscription_id  customer_id   plan_tier billing_cycle  \
# 0                1            1         Pro       Monthly
# 1                2            2     Starter        Annual
# 2                3            3    Business        Annual
# 3                4            4     Starter       Monthly
# 4                5            5         Pro        Annual
# 5                6            6         Pro        Annual
# 6                7            7     Starter       Monthly
# 7                8            8         Pro       Monthly
# 8                9            9    Business       Monthly
# 9               10           10  Enterprise        Annual
#
#   subscription_start_date subscription_end_date subscription_status  \
# 0              2025-06-21                  None              Active
# 1              2024-02-29                  None              Active
# 2              2025-12-10                  None              Active
# 3              2023-10-14                  None              Active
# 4              2023-05-21                  None              Active
# 5              2025-05-18                  None              Active
# 6              2023-08-15                  None              Active
# 7              2024-09-02                  None              Active
# 8              2024-08-28                  None              Active
# 9              2025-12-25            2026-01-25           Cancelled
#
#    monthly_recurring_revenue
# 0                      99.00
# 1                      24.65
# 2                     254.15
# 3                      29.00
# 4                      84.15
# 5                      84.15
# 6                      29.00
# 7                      99.00
# 8                     299.00
# 9                     849.15

# %%
print(f"\nStatus breakdown:")
print(subscriptions_df['subscription_status'].value_counts())

print(f"\nPlan tier vs company size correlation check:")
merged = subscriptions_df.merge(customers_df, on='customer_id')
print(merged.groupby('company_size_tier')['plan_tier'].value_counts())
# Out:
# Status breakdown:
# subscription_status
# Active       1493
# Cancelled     507
# Name: count, dtype: int64
#
# Plan tier vs company size correlation check:
# company_size_tier  plan_tier
# Enterprise         Enterprise    154
#                    Business       85
#                    Pro            46
#                    Starter        11
# Medium             Pro           306
#                    Business      264
#                    Starter       113
#                    Enterprise     57
# Small              Starter       465
#                    Pro           352
#                    Business      122
#                    Enterprise     25
# Name: count, dtype: int64

# %%
# Usage Events

# %%
# Assign each customer a usage personality - this drives their event pattern
personalities = ["Power User", "Steady User", "Declining User", "Sporadic User"]
personality_weights = [15, 45, 20, 20]  # most customers are "Steady"

customer_personality = {}
for cid in customers_df["customer_id"]:
    customer_personality[cid] = random.choices(personalities, weights=personality_weights)[0]

# Quick check
personality_counts = pd.Series(customer_personality.values()).value_counts()
print(personality_counts)
# Out:
# Steady User       890
# Sporadic User     405
# Declining User    392
# Power User        313
# Name: count, dtype: int64

# %%
# Generate Usage Events

# %%
feature_list = ["Dashboard", "Reports", "Task Board", "Automation", "Integrations", "Team Chat"]

usage_events = []
event_id_counter = 1

for idx, row in customers_df.iterrows():
    cid = row["customer_id"]
    signup = pd.to_datetime(row["signup_date"])
    personality = customer_personality[cid]
    
    # Find this customer's subscription end (if cancelled) to bound their activity window
    sub_row = subscriptions_df[subscriptions_df["customer_id"] == cid].iloc[0]
    if sub_row["subscription_status"] == "Cancelled":
        activity_end = pd.to_datetime(sub_row["subscription_end_date"])
    else:
        activity_end = datetime(2025, 12, 31)
    
    total_days = (activity_end - signup).days
    if total_days <= 0:
        continue
    
    current_day = 0
    while current_day < total_days:
        # Decide gap until next "active period" based on personality
        if personality == "Power User":
            gap = random.randint(0, 1)
            burst_length = random.randint(5, 15)
        elif personality == "Steady User":
            gap = random.randint(1, 4)
            burst_length = random.randint(2, 6)
        elif personality == "Declining User":
            # gap grows larger as time progresses - this IS the decline
            progress_ratio = current_day / total_days
            gap = random.randint(1, 3) + int(progress_ratio * 10)
            burst_length = max(1, random.randint(2, 6) - int(progress_ratio * 4))
        else:  # Sporadic User
            gap = random.randint(5, 20)
            burst_length = random.randint(1, 3)
        
        current_day += gap
        
        # Generate a burst of active days
        for b in range(burst_length):
            if current_day >= total_days:
                break
            event_date = signup + timedelta(days=current_day)
            usage_events.append({
                "event_id": event_id_counter,
                "customer_id": cid,
                "event_date": event_date.date(),
                "feature_used": random.choice(feature_list),
                "session_count": random.randint(1, 8),
                "event_type": "login"
            })
            event_id_counter += 1
            current_day += 1

usage_events_df = pd.DataFrame(usage_events)
print(f"Total usage events created: {len(usage_events_df)}")
usage_events_df.head(10)
# Out:
# Total usage events created: 505130
#    event_id  customer_id  event_date  feature_used  session_count event_type
# 0         1            1  2025-06-23     Dashboard              4      login
# 1         2            1  2025-06-24    Task Board              7      login
# 2         3            1  2025-06-25  Integrations              2      login
# 3         4            1  2025-06-26     Team Chat              1      login
# 4         5            1  2025-06-27  Integrations              6      login
# 5         6            1  2025-06-28  Integrations              8      login
# 6         7            1  2025-07-03     Dashboard              8      login
# 7         8            1  2025-07-04    Task Board              1      login
# 8         9            1  2025-07-05     Dashboard              4      login
# 9        10            1  2025-07-06  Integrations              4      login

# %%
# Check average gap between events per personality type
usage_events_df['event_date'] = pd.to_datetime(usage_events_df['event_date'])

events_per_customer = usage_events_df.groupby('customer_id').size().reset_index(name='total_events')
events_per_customer['personality'] = events_per_customer['customer_id'].map(customer_personality)

print(events_per_customer.groupby('personality')['total_events'].mean())
# Out:
# personality
# Declining User    157.676020
# Power User        462.444089
# Sporadic User      66.527500
# Steady User       306.266892
# Name: total_events, dtype: float64

# %%
# 1 First - Missing - feature_used

# %%
# Corruption 1: Randomly set ~2% of feature_used to None (missing data)
np.random.seed(100)  # different seed for corruption, just for variety
corrupt_mask = np.random.random(len(usage_events_df)) < 0.02
usage_events_df.loc[corrupt_mask, 'feature_used'] = None

print(f"Rows with missing feature_used: {usage_events_df['feature_used'].isna().sum()}")
# Out:
# Rows with missing feature_used: 10080

# %%
# 2 Duplicate Events

# %%
# Corruption 2: Duplicate ~1% of rows exactly (simulating a logging system 
# that double-recorded some events)
np.random.seed(101)
num_duplicates = int(len(usage_events_df) * 0.01)
duplicate_rows = usage_events_df.sample(num_duplicates, random_state=101).copy()

usage_events_df = pd.concat([usage_events_df, duplicate_rows], ignore_index=True)

print(f"Total rows after adding duplicates: {len(usage_events_df)}")
print(f"Duplicate rows added: {num_duplicates}")
# Out:
# Total rows after adding duplicates: 510181
# Duplicate rows added: 5051

# %%
# 3 Orphan Records

# %%
# Corruption 3: Add a handful of orphan events - customer_ids that don't exist
# in the customers table at all
np.random.seed(102)

num_orphans = 25
max_real_id = customers_df["customer_id"].max()

orphan_events = []
for i in range(num_orphans):
    fake_customer_id = max_real_id + random.randint(1, 500)  # guaranteed to not exist
    orphan_events.append({
        "event_id": usage_events_df["event_id"].max() + i + 1,
        "customer_id": fake_customer_id,
        "event_date": (datetime(2024, 1, 1) + timedelta(days=random.randint(0, 700))).date(),
        "feature_used": random.choice(feature_list),
        "session_count": random.randint(1, 8),
        "event_type": "login"
    })

orphan_df = pd.DataFrame(orphan_events)
usage_events_df = pd.concat([usage_events_df, orphan_df], ignore_index=True)

print(f"Total rows after adding orphans: {len(usage_events_df)}")

# Verify: these customer_ids should NOT exist in customers_df
orphan_check = usage_events_df[~usage_events_df["customer_id"].isin(customers_df["customer_id"])]
print(f"Confirmed orphan rows (customer_id not in customers table): {len(orphan_check)}")
# Out:
# Total rows after adding orphans: 510206
# Confirmed orphan rows (customer_id not in customers table): 25

# %%
# 4  Outlier Session Count

# %%
# Corruption 4: Inject a few extreme outlier session_count values
# (simulating bot-generated sessions or test accounts)
np.random.seed(103)

outlier_indices = usage_events_df.sample(15, random_state=103).index
usage_events_df.loc[outlier_indices, 'session_count'] = np.random.randint(500, 5000, size=15)

print("Outlier rows:")
print(usage_events_df.loc[outlier_indices, ['customer_id', 'event_date', 'session_count']])
# Out:
# Outlier rows:
#         customer_id           event_date  session_count
# 222706          884  2024-07-29 00:00:00           4447
# 427820         1690  2023-05-27 00:00:00           2219
# 161523          665  2024-10-04 00:00:00           4296
# 239840          958  2025-12-22 00:00:00            673
# 492732         1952  2025-07-31 00:00:00           4686
# 277221         1084  2024-09-17 00:00:00           4666
# 315978         1240  2025-05-17 00:00:00            510
# 317742         1246  2025-06-09 00:00:00           3900
# 268034         1050  2024-07-14 00:00:00           3269
# 411313         1633  2025-06-03 00:00:00           2671
# 373916         1485  2025-02-07 00:00:00            872
# 504738         1999  2024-12-20 00:00:00           4462
# 290613         1140  2024-07-31 00:00:00           2009
# 373605         1484  2025-12-22 00:00:00           3157
# 325295         1279  2023-02-18 00:00:00           1470

# %%
# 5 Usage After Subscription Cancellation

# %%
# Corruption 5: Inject usage events that occur AFTER the customer's 
# subscription was cancelled - a business rule violation
np.random.seed(104)

cancelled_customers = subscriptions_df[subscriptions_df["subscription_status"] == "Cancelled"]
sample_cancelled = cancelled_customers.sample(min(20, len(cancelled_customers)), random_state=104)

violation_events = []
for idx, row in sample_cancelled.iterrows():
    cid = row["customer_id"]
    end_date = pd.to_datetime(row["subscription_end_date"])
    
    # Event happens 5-30 days AFTER cancellation - shouldn't be possible
    violation_date = end_date + timedelta(days=random.randint(5, 30))
    
    violation_events.append({
        "event_id": usage_events_df["event_id"].max() + len(violation_events) + 1,
        "customer_id": cid,
        "event_date": violation_date.date(),
        "feature_used": random.choice(feature_list),
        "session_count": random.randint(1, 8),
        "event_type": "login"
    })

violation_df = pd.DataFrame(violation_events)
usage_events_df = pd.concat([usage_events_df, violation_df], ignore_index=True)

print(f"Total rows after adding violations: {len(usage_events_df)}")
print(f"Violation events added: {len(violation_df)}")
# Out:
# Total rows after adding violations: 510226
# Violation events added: 20

# %%
# Payments Table

# %%
payments = []
payment_id_counter = 1

for idx, row in subscriptions_df.iterrows():
    cid = row["customer_id"]
    sub_id = row["subscription_id"]
    start = pd.to_datetime(row["subscription_start_date"])
    billing = row["billing_cycle"]
    mrr = row["monthly_recurring_revenue"]
    
    if row["subscription_status"] == "Cancelled":
        end = pd.to_datetime(row["subscription_end_date"])
    else:
        end = datetime(2025, 12, 31)
    
    # Determine billing interval in days
    interval_days = 30 if billing == "Monthly" else 365
    payment_amount = mrr if billing == "Monthly" else mrr * 12
    
    current_date = start
    while current_date <= end:
        # Small chance a payment fails
        payment_failed = random.random() < 0.05
        
        payments.append({
            "payment_id": payment_id_counter,
            "customer_id": cid,
            "subscription_id": sub_id,
            "payment_date": current_date.date(),
            "amount": payment_amount,
            "payment_status": "Failed" if payment_failed else "Success"
        })
        payment_id_counter += 1
        current_date += timedelta(days=interval_days)

payments_df = pd.DataFrame(payments)
print(f"Total payments created: {len(payments_df)}")
payments_df.head(10)
# Out:
# Total payments created: 18347
#    payment_id  customer_id  subscription_id payment_date  amount  \
# 0           1            1                1   2025-06-21    99.0
# 1           2            1                1   2025-07-21    99.0
# 2           3            1                1   2025-08-20    99.0
# 3           4            1                1   2025-09-19    99.0
# 4           5            1                1   2025-10-19    99.0
# 5           6            1                1   2025-11-18    99.0
# 6           7            1                1   2025-12-18    99.0
# 7           8            2                2   2024-02-29   295.8
# 8           9            2                2   2025-02-28   295.8
# 9          10            3                3   2025-12-10  3049.8
#
#   payment_status
# 0        Success
# 1        Success
# 2        Success
# 3        Success
# 4        Success
# 5        Success
# 6        Success
# 7        Success
# 8        Success
# 9        Success

# %%
print(f"Total payments: {len(payments_df)}")
print(f"\nPayment status breakdown:")
print(payments_df['payment_status'].value_counts())
print(f"\nAmount stats:")
print(payments_df['amount'].describe())
# Out:
# Total payments: 18347
#
# Payment status breakdown:
# payment_status
# Success    17420
# Failed       927
# Name: count, dtype: int64
#
# Amount stats:
# count    18347.000000
# mean       457.418662
# std       1228.065959
# min         29.000000
# 25%         29.000000
# 50%         99.000000
# 75%        299.000000
# max      10189.800000
# Name: amount, dtype: float64

# %%
# 1 Duplicate Payment Transactions

# %%
np.random.seed(105)
num_duplicates = int(len(payments_df) * 0.015)
duplicate_payments = payments_df.sample(num_duplicates, random_state=105).copy()

payments_df = pd.concat([payments_df, duplicate_payments], ignore_index=True)
print(f"Total after duplicates: {len(payments_df)}")
# Out:
# Total after duplicates: 18622

# %%
# Successful Payments with 0 amount

# %%
np.random.seed(106)
zero_amount_indices = payments_df[payments_df["payment_status"] == "Success"].sample(12, random_state=106).index
payments_df.loc[zero_amount_indices, "amount"] = 0.0
print(f"Zero-amount success payments: {(payments_df['amount'] == 0).sum()}")
# Out:
# Zero-amount success payments: 12

# %%
# Inconsistent Status Casing

# %%
np.random.seed(107)
casing_variants = {"Success": ["success", "SUCCESS", "Success"], "Failed": ["failed", "FAILED", "Failed"]}

def randomize_casing(status):
    return random.choice(casing_variants[status])

# Apply inconsistent casing to a random 30% of rows, leave the rest as-is
casing_mask = np.random.random(len(payments_df)) < 0.30
payments_df.loc[casing_mask, "payment_status"] = payments_df.loc[casing_mask, "payment_status"].apply(randomize_casing)

print(payments_df["payment_status"].value_counts())
# Out:
# payment_status
# Success    14119
# success     1789
# SUCCESS     1771
# Failed       771
# FAILED        89
# failed        83
# Name: count, dtype: int64

# %%
# Connect to the Database

# %%
from sqlalchemy import create_engine

DB_PASSWORD = "qcommerce123"
DB_NAME = "saas_health"

engine = create_engine(f'postgresql+psycopg2://postgres:{DB_PASSWORD}@localhost:5432/{DB_NAME}')

print("Engine created successfully")
# Out:
# Engine created successfully

# %%
customers_df.to_sql('customers', engine, if_exists='replace', index=False)
print("customers loaded")

subscriptions_df.to_sql('subscriptions', engine, if_exists='replace', index=False)
print("subscriptions loaded")

usage_events_df.to_sql('usage_events', engine, if_exists='replace', index=False)
print("usage_events loaded")

payments_df.to_sql('payments', engine, if_exists='replace', index=False)
print("payments loaded")

print("\nAll tables loaded successfully!")
# Out:
# customers loaded
# subscriptions loaded
# usage_events loaded
# payments loaded
#
# All tables loaded successfully!

# %%
check1 = pd.read_sql("SELECT COUNT(*) as total FROM customers", engine)
check2 = pd.read_sql("SELECT COUNT(*) as total FROM subscriptions", engine)
check3 = pd.read_sql("SELECT COUNT(*) as total FROM usage_events", engine)
check4 = pd.read_sql("SELECT COUNT(*) as total FROM payments", engine)

print(f"Customers: {check1['total'][0]}")
print(f"Subscriptions: {check2['total'][0]}")
print(f"Usage events: {check3['total'][0]}")
print(f"Payments: {check4['total'][0]}")
# Out:
# Customers: 2000
# Subscriptions: 2000
# Usage events: 510226
# Payments: 18622
